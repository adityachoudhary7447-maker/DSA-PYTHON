# %%
#if ch 
def ifpresent (s,ch):
    pass

s="abcdef"
ch='c'
print(ifpresent(s,ch))
# Out:
# None

# %%
def replace (s):
    if len (s) ==0 or len(s) == 1:
        return s

    if s[0] =="p" and s[1] =='1':
        return '3.14' + replace (s[]
