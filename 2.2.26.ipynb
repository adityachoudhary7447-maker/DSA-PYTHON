# %%
#Questions discussed:
#WAP to print 1 to n recursively.
#WAP to print n to 1 recursively.
#Find sum of first 10 natural numbers recursively.
#Find sum of all elements of array recursively
#Given an array of length N and an integer x, you need to find if x is present in the array or not. Return true or false.

#HW QUESTIONS:

#Find Factorial recursive.
#Check if list is sorted or not (using slicing)
#Check if list is sorted or not (using index reference) - not using the extra space

ARRAY QUESTIONS:
Given an array of integers arr[], the task is to find the maximum and minimum elements in the array using the minimum number of comparisons.
Reverse the Array: Reverse an array arr[]. Reversing an array means rearranging the elements such that the first element becomes the last, the second element becomes second last and so on.
Kth Smallest: Given an integer array arr[] and an integer k, your task is to find and return the kth smallest element in the given array.
Sort 0s, 1s and 2s: Given an array arr[] containing only 0s, 1s, and 2s. Sort the array in ascending order. Note: You need to solve this problem without utilizing the built-in sort function.
Move all negative numbers to beginning and positive to end with constant extra space.
Input: -12, 11, -13, -5, 6, -7, 5, -3, -6 
Output: -12 -13 -5 -7 -3 -6 11 6 5

# %%
#Given an array of integers arr[], the task is to find the maximum and minimum elements in the array using the minimum number of comparisons.
def min_max (arr):
    n = len (arr)
    maxele = -1
    minele = 100000000

# %%
#WAP to print 1 to n recursively.
def print1ton (n):
    if n == 1:
        return 1
    smalloutput = print1ton(n-1)


    print (n)
    return

n = int(input())
print1ton(n)
# Out:
#  10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10

# %%
def print1ton(n):

    if n == 1:
        return 1
    smallOutput = print1ton(n-1)

    print(n)
    return


n = int(input())
print1ton(n)
# Out:
#  10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
