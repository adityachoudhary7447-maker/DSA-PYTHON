# %%
Questions Discussed:
Check if List is Sorted (Slicing + Recursive)
Check if List is Sorted (Indexing + Recursive)
Return the first index of integer x present in the array (use slicing)
Return the first index of integer x present in the array (without using slicing)
Return the last index of integer x present in the array (use slicing)
Return the last index of integer x present in the array (without using slicing) - check from rear
Return the last index of integer x present in the array (without using slicing) - check from front

ARRAY QUESTIONS:
Union of Arrays with Duplicates: You are given two arrays a[] and b[], return the Union of both the arrays in any order. The Union of two arrays is a collection of all distinct elements present in either of the arrays. If an element appears more than once in one or both arrays, it should be included only once in the result.
Rotate Array by One: Given an array arr, rotate the array by one position in clockwise direction.
Input: arr[] = [1, 2, 3, 4, 5] 
Output: [5, 1, 2, 3, 4]
Kadane’s Algorithim: Given an integer array arr[], find the subarray (containing at least one element) which has the maximum possible sum, and return that sum. Note: A subarray is a continuous part of an array.

# %%
#Check if List is Sorted (Slicing + Recursive)

# %%
#Return the first index of integer x present in the array (use slicing)
def firstindex(arr,x):

    if len(arr)== 0:
        return -1
    if arr[0]== x:
        return 0

    smalloutput = firstindex (arr[1:],x)

    if smalloutput == -1:
        return -1
    else:
        return smalloutput +1
        
a =[1,2,3,4,5,6,7,8,9]
x = 7
print(firstindex (a,x))
# Out:
# 6

# %%
def lastindexbetter (arr,x,si):
    if si ==len (arr):
        return -1

    smalloutput = lastindexbetter(arr,x,si+1)

    if smalloutput != -1:
        return smalloutput
    else:
        if arr[si] ==x:
            return si
        return -1
        
        
a =(1,3,7,8,5,4,3,6,7,6,5)
x= 7
print(lastindexbetter(arr,x,0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 17
#      15 a =(1,3,7,8,5,4,3,6,7,6,5)
#      16 x= 7
# ---> 17 print(lastindexbetter (arr,x,0))
#
# NameError: name 'arr' is not defined

# %%
#Kadane’s Algorithim: Given an integer array arr[], find the subarray (containing at least one element)--
#--which has the maximum possible sum, and return that sum. Note: A subarray is a continuous part of an array.
def kadanesalgo (arr):
    res = arr [0]
    maxsum = res

    for i in range (1,len(arr)):
       maxsum = max (maxsum +arr[i], res)
        res = max
