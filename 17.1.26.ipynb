# %%
' WAP to check the input number is a Buzz number or not.'
n = int (input ("enter the no "))
if n%7 ==0:
    print (n,"is a Buzz number")
elif n%10 ==7:
   print (n,"is a Buzz number")
else:
    print (n,"is not a Buzz number")
# Out:
# enter the no  107
# 107 is a Buzz number
