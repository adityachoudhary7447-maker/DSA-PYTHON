# %%
def binarysearch (arr, k):
    n = len (arr)
    si= 0
    ei = (n-1)

    while (si<=ei):
        mid =(si +ei )//2
        
        if arr[mid]== k:
            return mid 

        elif arr[mid]< k:
            si = mid +1
        else:
            ei = mid -1
            
    return -1

arr = [1,3,7,16,18,26,40]
binarysearch (arr, 18)
# Out:
# 4

# %%
def binaryrecursive (arr,k,si,ei):
    if si> ei:
        return -1

    mid = (si+ei)//2
    if arr [mid]< k:
        return mid
    elif arr[mid] < k:
        return binaryrecursive(arr,ele,si,mid-1)
    else:
        return binaryrecursive(arr,ele,mid+1,ei)

ans = binaryrecursive([1,2,3,4,5,6,7,8,9],5,0,7)
print(ans)
# Out:
# 3
